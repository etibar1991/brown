# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Этибар, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы». Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Пример можно посмотреть в самом первом проекте (Музыка городов)
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#импорт библиотек

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
#читаем файл

# %%
data.head(20)
#выводим первые 20 строчек датафрейма
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
data.info()
#получаем общую информацию о датафрейме
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.describe()
#выводим таблицу с количественными данными в строчках
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# Из общей информации видно, что в файле 22 столбца. По количеству ячеек видно, что часть столбцов содержит пропуски. Также названия столбцов стилистическине идентичны.
# Из выведенной таблицы с количественными данными можно  увидеть разброс значений. Например, максимальное кол-во комнат - 19. Или некорректные цифры - общее кол-во этажей не целое число.

# %%
data.hist(figsize = (15,20));


#выведем общую гистограмму для таблицы

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Предупреждения перед графиками можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# Вывод: информации для анализа много, но для дальнейшего анализа нужно совершить предобработку данных.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 
                        'parks_around3000': 'parks_around_3000', 
                        'ponds_around3000': 'ponds_around_3000',
                        'studio': 'is_studio',
                        'open_plan': 'is_open_plan'
                       })
data.columns
#переименовываем столбцы для единого стиля
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'is_studio', 'is_open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
data.isnull().sum()
#выводим общее количество пропусков по столбцам
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# is_studio                   0
# is_open_plan                0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В 14 столбцах есть пропуски. Часть из них критично заполнить данными, часть можно удалить/оставить.
# Далее посмотрим детально на каждый столбец.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также, помимо абсолютных значений мы можем посмотреть долю пропусков, и на основании этого принять решение о удалении, замене либо игнорировании пропусков, например: `pd.DataFrame(round(df.isna().mean().sort_values(ascending=False)*100,1)).style.background_gradient('coolwarm')`
#
#
# </div>

# %% [markdown]
# *total_images*

# %%
data['total_images'].describe()
#детальная информация о столбце
# Out:
# count    23699.000000
# mean         9.858475
# std          5.682529
# min          0.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         50.000000
# Name: total_images, dtype: float64

# %% [markdown]
# В этом столбце пропусков нет. Среднее количество фотографий к объявлению - почти 10. Максимальное количество -50, минимальное количеств - 0.
# посмотрим много ли объявлений с нулем в фотографиях.

# %%
print(sum(data['total_images'] == 0))
no_image_percent = sum(data['total_images'] == 0)/ data['total_images'].count()
no_image_percent
#сумма объявлений без фото и их процент от общего числа
# Out:
# 1059
# 0.04468542976496898

# %% [markdown]
# Процент объявлений без фото - 5%. Оставим эти данные без изменений.

# %% [markdown]
# *last_price*

# %%
print(data['last_price'].min())
print(data['last_price'].max())
data['last_price'].mean()
# Out:
# 12190.0
# 763000000.0
# 6541548.771551542

# %% [markdown]
# Пропусков нет. Минимальная цена квартиры - 12 тысяч. Максимальная 763 млн. Средняя цена - 6,5 млн.
# Нужно внимательно посмотреть на макс и мин цену в объявлениях.

# %%
data[data['last_price'] < 100000]

#посмотрим на квартиры дешевле 100 тысяч.
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7     12190.0       109.0  2019-03-20T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 8793            2.75          25.0         32.0     25          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# 8793          40.5      NaN  Санкт-Петербург           36421.0
#
#      city_centers_nearest  parks_around_3000  parks_nearest  \
# 8793               9176.0                1.0          805.0
#
#       ponds_around_3000  ponds_nearest  days_exposition
# 8793                0.0            NaN              8.0
#
# [1 rows x 22 columns]

# %%
data[data['last_price'] > 300000000]
#и на квартиры дороже 300 млн.
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 1436             19  330000000.0       190.0  2018-04-04T00:00:00      3
# 12971            19  763000000.0       400.0  2017-09-30T00:00:00      7
# 14706            15  401300000.0       401.0  2016-02-20T00:00:00      5
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1436              3.5           7.0         95.0      5          NaN  ...
# 12971             NaN          10.0        250.0     10          NaN  ...
# 14706             NaN           9.0        204.0      9        False  ...
# 19540             2.8          25.0        409.7     25          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 1436           40.0      NaN  Санкт-Петербург           23011.0
# 12971           NaN      2.0  Санкт-Петербург           25108.0
# ...

# %% [markdown]
# Квартира дешевле 100 тысяч всего одна. Исходя из остальных данных можнон сделать вывод, что есть ошибка в цифрах и стоимость квартиры не 12 тысяч, а 12 млн. Исправим это.
# Квартиры дороже 300 млн. - 4. При этом квартира за 763 млн выбиваетя даже из этого списка. Удалим ее.

# %%
data['last_price'] = data['last_price'].replace(12190, 12190000)

#заменим цену

# %%
data = data.loc[data['last_price'] < 421000000]
#перезапишем датафрейм без объявлений дороже 421 млн.

# %%
data.info()
#снова выведем инфо по датафрейму
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23698 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23698 non-null  int64
#  1   last_price            23698 non-null  float64
#  2   total_area            23698 non-null  float64
#  3   first_day_exposition  23698 non-null  object
#  4   rooms                 23698 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23612 non-null  float64
#  7   living_area           21795 non-null  float64
#  8   floor                 23698 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  is_studio             23698 non-null  bool
#  11  is_open_plan          23698 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12179 non-null  float64
#  14  locality_name         23649 non-null  object
# ...

# %% [markdown]
# *total_area, living_area, kitchen_area*

# %%
data['total_area'].describe()
#опишем детально
# Out:
# count    23698.000000
# mean        60.334319
# std         35.586498
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.875000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data['living_area'].describe()
# Out:
# count    21795.000000
# mean        34.447963
# std         21.982515
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
data['kitchen_area'].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# В total_area пропусков нет. Большинство квартир с квадратурой до 70 кв.м. В living_area и в kitchen_area есть пропуски.
# Сначала их заполним.

# %%
for room in data['rooms'].unique():
    data.loc[(data['rooms'] == room) & (data['living_area'].isna()), 'living_area'] = \
    data.loc[(data['rooms'] == room), 'living_area'].median()
#заполним пропуски используя логический цикл по медианной жилой квадратуры количества комнат

# %%
for room in data['rooms'].unique():
    
    data.loc[(data['rooms'] == room) & (data['kitchen_area'].isna()), 'kitchen_area'] = \
    data.loc[(data['rooms'] == room), 'kitchen_area'].mean()
#аналогично kitchen_area, только вместо медианы берем среднюю, т.к для некоторых срезв недостачтоно данных

# %% [markdown]
# А теперь посмотрим на аномалии в данных этих столбцов.

# %%
data[data['total_area'] < 15]
#смотрим на строчки, в которых общая площадь меньше 15
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17961             3   1400000.0        13.0  2017-12-03T00:00:00      1
# 19546             3   1850000.0        13.0  2019-03-11T00:00:00      1
# 19558             2   1686000.0        13.2  2018-12-17T00:00:00      1
# 19642             5   1190000.0        14.0  2018-07-29T00:00:00      1
# 19807             0   3800000.0        13.0  2018-07-04T00:00:00      1
# 19904             4   2400000.0        12.0  2017-07-19T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 17961            2.60           9.0         17.6      1          NaN  ...
# 19546            3.40           5.0         17.6      2        False  ...
# 19558             NaN           5.0         17.6      1          NaN  ...
# 19642             NaN           5.0         11.0      1          NaN  ...
# 19807             NaN           5.0         10.0      3          NaN  ...
# ...

# %% [markdown]
# Кроме одной строчки остальные странные. Жилая площадь + площадь кухни больше общей. Предлагаю удалить все эти значения.

# %%
data = data[data['total_area'] > 15]
#оставим только объявления с общей площадью больше 15

# %%
data['difference'] = data['total_area'] - data['living_area'] - data['kitchen_area']
display(sum(data['difference'] < 0))
data = data[data['difference'] > 0]    # удаляем те объявления, в которых общая площадь меньше суммы плозади кухни и жилой
data = data.drop('difference', axis=1)
# Out:
# 346

# %%
data.isnull().sum()
#выведем снова пропуски
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           8859
# floors_total               75
# living_area                 0
# floor                       0
# is_apartment            20382
# is_studio                   0
# is_open_plan                0
# kitchen_area                0
# balcony                 11216
# locality_name              48
# airports_nearest         5293
# city_centers_nearest     5270
# parks_around_3000        5269
# parks_nearest           15130
# ponds_around_3000        5269
# ponds_nearest           14166
# days_exposition          3134
# dtype: int64

# %% [markdown]
# *first_day_exposition, days_exposition*

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],
                                              
format='%Y-%m-%dT%H:%M:%S')
print(data['first_day_exposition'].min())
print(data['first_day_exposition'].max())
#переведем строку в формат даты и посмотрим максимальное и минимальное значение
# Out:
# 2014-11-27 00:00:00
# 2019-05-03 00:00:00

# %% [markdown]
# Первое объявление - 27 ноября 2014 года, день выгрузки - 03 мая 2019 года.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['first_day_exposition']`. Тогда пандас автоматически переведет список столбцов в даты.
# </div>

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# В этом столбце есть пропуски. Они объясняются тем, что недвижимость еще продается.
# Максимальное кол-во дней в продаже 1580, минимальное 1 день. Так как можно предположить, что все пропуски это квартиры еще на продаже, поэтому предлагаю не заполнять эти пропуски ничем.

# %% [markdown]
# *floors, floors_total*

# %%
data['floor'].describe()
# Out:
# count    23085.000000
# mean         5.860386
# std          4.849784
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# Пропусков нет. Минимально - 1 этаж, максимально - 33.

# %%
data['floors_total'].describe()
#описываем детально
# Out:
# count    23010.000000
# mean        10.597957
# std          6.543176
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         15.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Есть пропуски, которые нужно заменить. Заменим их на этаж объявления, в котором пропуск есть.

# %%
data.loc[data['floors_total'].isnull(), 'floors_total'] = data.loc[data['floors_total'].isnull(), 'floor']
#заменили на значение из соотвествующего этажа объявления

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Доля пропусков здесь менее 5% и для экономии времени их можно удалить.
# </div>

# %% [markdown]
# *ceiling_height*

# %%
data['ceiling_height'].describe()
#описываем
# Out:
# count    14226.000000
# mean         2.759954
# std          0.910441
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Есть пропуски, которые мы заменим средним значением по столбцу, округлив до сотых после запятой.

# %%
data['ceiling_height'] = round(data['ceiling_height'].fillna(data['ceiling_height'].mean()),2)
#заполним пропуски в столбце ceiling_height средним значением

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно. Потолки это довольно стандартизированная величина, поэтому пропуски можно безболезненно заменить их медианой.
# </div>

# %% [markdown]
# *balcony*

# %%
data['balcony'].describe()
#описываем
# Out:
# count    11869.000000
# mean         1.146685
# std          1.074007
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# Есть пропуски. Предполагаем, что это дома без балконов. Поэтому пропуски заменим на 0

# %%
data['balcony'] = data['balcony'].fillna(0)
#заменяем на 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, люди не заполняют "не выгодные" для продажи квартиры характеристики.
# </div>

# %% [markdown]
# *is_apartment*

# %%
data['is_apartment'].describe()
#считаем кол-во значений
# Out:
# count      2703
# unique        2
# top       False
# freq       2658
# Name: is_apartment, dtype: object

# %% [markdown]
# в этом столбце есть пропуски. К тому же значения надо перевести в буллев. Для этого применим логику, что если есть пропуск - значит недвижимость не апартамент. Присвоим пропускам значение пробел.

# %%
data['is_apartment'] = data['is_apartment'].fillna('')
#присвоили пробел пропускам

# %%
data['is_apartment'] = data['is_apartment'].astype('bool') 
#переведоим в bool
data['is_apartment'].value_counts()
#проверяем
# Out:
# False    23040
# True        45
# Name: is_apartment, dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно, либо это апартаменты, либо нет. Булев тип подходит лучше всего.
# </div>

# %%
data.isnull().sum()
#снова выведем пропуски
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# is_studio                   0
# is_open_plan                0
# kitchen_area                0
# balcony                     0
# locality_name              48
# airports_nearest         5293
# city_centers_nearest     5270
# parks_around_3000        5269
# parks_nearest           15130
# ponds_around_3000        5269
# ponds_nearest           14166
# days_exposition          3134
# dtype: int64

# %% [markdown]
# *locality_name*

# %%
data['locality_name'].describe()
#опишем
# Out:
# count               23037
# unique                361
# top       Санкт-Петербург
# freq                15389
# Name: locality_name, dtype: object

# %% [markdown]
# Есть пропуски в locality_name, но их доля слишком мала, чтобы влиять на результаты. Плэтому удаляем.

# %%
data = data.dropna(subset=['locality_name'])

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Согласен
# </div>

# %% [markdown]
# Согласно документации в этом столбце есть дубликаты. давайте посмотрим

# %%
data['locality_name'].unique()
#выводим список уникальных значений в столбце
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'посёлок Плодовое', 'деревня Заклинье', 'поселок Торковичи',
#        'поселок Первомайское', 'Красное Село', 'посёлок Понтонный',
#        'Сясьстрой', 'деревня Старая', 'деревня Лесколово', 'Сланцы',
# ...

# %% [markdown]
# Нам нужно заменить "ё" на "е" и "городской поселок" на "поселок городского типа"

# %%
data['locality_name'] = data['locality_name'].str.replace('посёлок', 'поселок')
#заменяем ё на е

# %%
data['locality_name'] = data['locality_name'].str.replace('городской поселок', 'поселок городского типа')
#заменяем на пгт

# %%
data['locality_name'].unique()
#проверяем
# Out:
# array(['Санкт-Петербург', 'поселок Шушары',
#        'поселок городского типа Янино-1', 'поселок Парголово',
#        'поселок Мурино', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок Плодовое', 'деревня Заклинье', 'поселок Торковичи',
#        'поселок Первомайское', 'Красное Село', 'поселок Понтонный',
#        'Сясьстрой', 'деревня Старая', 'деревня Лесколово', 'Сланцы',
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %% [markdown]
# *airports_nearest, city_centers_nearest, parks_nearest*

# %% [markdown]
# В этих столбцах есть пропуски. Заменим их на средние значения, сгрупированные по наименованию населенного пункта.

# %%
for name in data['locality_name'].unique():
    data.loc[(data['locality_name'] == name) & (data['airports_nearest'].isna()), 'airports_nearest'] = \
    data.loc[(data['locality_name'] == name), 'airports_nearest'].mean()
#аэропорты

# %%
for name in data['locality_name'].unique():
    data.loc[(data['locality_name'] == name) & (data['city_centers_nearest'].isna()), 'city_centers_nearest'] = \
    data.loc[(data['locality_name'] == name), 'city_centers_nearest'].mean()
#центр города

# %%
for name in data['locality_name'].unique():
    data.loc[(data['locality_name'] == name) & (data['parks_nearest'].isna()), 'parks_nearest'] = \
    data.loc[(data['locality_name'] == name), 'parks_nearest'].mean()
#парки

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Картографию я бы не трогал, тк вероятно расстояние автоматически не подсчиталось до объектов, или может там нет парков прудов и прочего. Как вариант конечно можно было провести группировку по населенному пункту с измерением среднего показателя, далее заполнить соответствующим значением, но не думаю, что мы бы много записей спасли
# </div>

# %%
data.isnull().sum()
#посмотрим пропуски
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# is_studio                   0
# is_open_plan                0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         4700
# city_centers_nearest     4700
# parks_around_3000        5261
# parks_nearest            5738
# ponds_around_3000        5261
# ponds_nearest           14142
# days_exposition          3133
# dtype: int64

# %% [markdown]
# В столбцах airports_nearest, city_centers_nearest, parks_nearest остались еще пропуски. Так как данные картографические - заменить их чем-то еще нельзя. Оставляем так.

# %% [markdown]
# Проверим есть ли 0 в столбце airports_nearest

# %%
data[data['airports_nearest'] == 0]
#квартира в аэропорту это странно
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21085             0   7000000.0        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 21085             2.7           9.0         19.8      3         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 21085           6.0      2.0  Санкт-Петербург               0.0
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 21085              22801.0                0.0     498.713409
#
#        ponds_around_3000  ponds_nearest  days_exposition
# 21085                0.0            NaN             60.0
#
# [1 rows x 22 columns]

# %% [markdown]
# удаляем эту строчку

# %%
data = data.query('airports_nearest != 0')

# %%
data.head(10)
#выведем 10 стрчоек датафрейма
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1            2.76          11.0        18.60      1         False  ...
# ...

# %% [markdown]
# *parks_around_3000, ponds_around_3000*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23036 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23036 non-null  int64
#  1   last_price            23036 non-null  float64
#  2   total_area            23036 non-null  float64
#  3   first_day_exposition  23036 non-null  datetime64[ns]
#  4   rooms                 23036 non-null  int64
#  5   ceiling_height        23036 non-null  float64
#  6   floors_total          23036 non-null  float64
#  7   living_area           23036 non-null  float64
#  8   floor                 23036 non-null  int64
#  9   is_apartment          23036 non-null  bool
#  10  is_studio             23036 non-null  bool
#  11  is_open_plan          23036 non-null  bool
#  12  kitchen_area          23036 non-null  float64
#  13  balcony               23036 non-null  float64
# ...

# %% [markdown]
# В этих столбцах тоже есть пропуски. Заменим их на нули по логике, как и в балконах. Приведем все к цельночисловому значению.

# %%
data['ponds_around_3000'] = data['ponds_around_3000'].fillna(0).astype('int')
data['parks_around_3000']= data['parks_around_3000'].fillna(0).astype('int')

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# is_studio                   0
# is_open_plan                0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         4700
# city_centers_nearest     4700
# parks_around_3000           0
# parks_nearest            5738
# ponds_around_3000           0
# ponds_nearest           14141
# days_exposition          3133
# dtype: int64

# %% [markdown]
# Разберемся с оставшимися аномалиями.

# %% [markdown]
# В столбце ceiling_height удаляем все строки, в которых высота потолков меньше 2 метров. Теперь посмотрим на все, что выше 5 метров.

# %%
data[data['ceiling_height'] > 5] #проверяем
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 355              17    3600000.0        55.2           2018-07-12      2
# 464              15   66571000.0       280.3           2015-06-11      6
# 1026             20  155000000.0       310.0           2018-10-12      5
# 1388             20   59800000.0       399.0           2015-01-21      5
# 3148             14    2900000.0        75.0           2018-11-12      3
# 3474              3    1400000.0        30.0           2018-03-16      1
# 4643              0    4300000.0        45.0           2018-02-01      2
# 5076              0    3850000.0        30.5           2018-10-03      1
# 5246              0    2500000.0        54.0           2017-10-13      2
# 5669              4    4400000.0        50.0           2017-08-08      2
# 5807             17    8150000.0        80.0           2019-01-09      2
# 5863             20    5650000.0        45.0           2018-08-15      1
# ...

# %%
data['ceiling_height'] = data['ceiling_height'].replace([20,22.6,24,25,26,27,32], [2,2.26,2.4,2.5,2.6,2.7,3.2])

# %%
data = data.query('ceiling_height < 5')
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %%
data[data['floors_total'] > 59] #аномальное значение total_floors в Кронштадте
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 2253            12   3800000.0        45.5           2018-06-28      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2253            2.88          60.0         27.4      4         False  ...
#
#       kitchen_area  balcony  locality_name  airports_nearest  \
# 2253           7.4      0.0      Кронштадт           67763.0
#
#      city_centers_nearest  parks_around_3000  parks_nearest  \
# 2253              49488.0                  2          342.0
#
#       ponds_around_3000  ponds_nearest  days_exposition
# 2253                  3          614.0            166.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Скорее всего подразумевалось, что кол-во этажей - 6, а не 60. Исправим.

# %%
data['floors_total'] = data['floors_total'].replace(60, 6)

# %% [markdown]
# Посмотрим столбец rooms

# %%
data[data['rooms'] < 10] #удалим все строки с кол-вом комнат больше 10
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data = data.query('rooms < 10') #удалим все строки с кол-вом комнат больше 10

# %% [markdown]
# Теперь проверим аномалии в столбцах связанных с площадью.

# %%
print(data['total_area'].min())

data['total_area'].max() #посмотрим макс и мин значения
# Out:
# 17.0
# 631.2

# %%
data = data.query('total_area > 20') #оставляем только те строки, где общай площадь больше 20

# %%
data[data['total_area'] > 500] #есть аномальное значение больше 500. Удалим
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 3117             19  140000000.0       631.0           2019-03-30      7
# 4237              1   50000000.0       517.0           2017-10-14      7
# 8018             20   84000000.0       507.0           2015-12-17      5
# 12859            20  140000000.0       631.2           2019-04-09      7
# 15651            20  300000000.0       618.0           2017-12-18      7
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3117             2.76           5.0        145.0      5         False  ...
# 4237             2.76           4.0        332.0      3         False  ...
# 8018             4.45           7.0        301.5      7          True  ...
# 12859            3.90           4.0        322.3      4         False  ...
# 15651            3.40           7.0        258.0      5         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data = data.query('total_area < 500') 
data.head(30)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %%
print(data['living_area'].max())
data['living_area'].min() #посмотрим на мин и макс значения в этом столбце
# Out:
# 347.5
# 2.0

# %%
data[data['living_area'] < 10] #жилая площадь маленькая, но видим что большая кухня. Оставим данные
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 114               5   4000000.0       21.40           2019-02-07      1
# 680              14   7200000.0       43.00           2017-10-31      1
# 1326              8   8100000.0       52.00           2017-01-29      2
# 2309             10   4200000.0       62.40           2017-06-15      2
# 3242              7   4440000.0       41.00           2017-07-02      1
# 4100             17   5300000.0       34.80           2017-06-19      1
# 7312              8   3400000.0       27.00           2018-02-21      2
# 8325              9   4800000.0       52.00           2017-10-25      2
# 13915            20   6350000.0       52.00           2018-02-06      2
# 15833            20   4600000.0       33.00           2017-01-01      1
# 16431            13   3799000.0       31.00           2018-04-12      1
# 17248            20   5300000.0       33.00           2017-04-14      1
# ...

# %%
data[data['living_area'] > 300] #тоже правдоподобные цифры, т.к. общая площадь большая
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 660               3  49950000.0       483.9           2017-10-04      7
# 12401            20  91500000.0       495.0           2017-06-19      7
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 660              3.20           6.0        312.5      4         False  ...
# 12401            4.65           7.0        347.5      7         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 660            26.4      0.0  Санкт-Петербург       23079.00000
# 12401          25.0      0.0  Санкт-Петербург       28099.67442
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 660                  945.0                  3          461.0
# 12401               5735.0                  2          110.0
#
#        ponds_around_3000  ponds_nearest  days_exposition
# 660                    3           22.0            391.0
# ...

# %%
print(data['kitchen_area'].max())
data['kitchen_area'].min() #посмотрим на мин и макс значения в этом столбце
# Out:
# 107.0
# 1.3

# %%
data[data['kitchen_area'] < 3] #строчка с индексом 7950 вызывает сомнение по размеру кухни, но оставим так
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 906              15   2600000.0       27.00           2017-07-10      1
# 6262              9   3100000.0       24.00           2018-06-25      2
# 7950              3   5967734.0       66.40           2017-02-07      2
# 9138             17   2920000.0       23.29           2018-12-12      1
# 11033             6   5350000.0       32.00           2016-04-20      1
# 16367             2   2720000.0       25.70           2017-10-30      1
# 17834             5   2940000.0       34.70           2017-10-09      1
# 20217             7   4250000.0       28.50           2019-05-01      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 906              2.75          23.0         18.0     18         False  ...
# 6262             3.00           5.0         16.0      5         False  ...
# 7950             2.76           4.0         44.4      2         False  ...
# ...

# %%
data[data['kitchen_area'] > 100] #есть вероятность, что перепутали показатели living_area и kitchen_area. Удалим строку
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2489              9  12500000.0       255.0           2017-04-21      3
# 20215             2  85000000.0       249.7           2018-02-01      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2489             2.76           2.0        153.9      2         False  ...
# 20215            2.76          10.0         72.0      9         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 2489          100.7      0.0  Санкт-Петербург           29544.0
# 20215         107.0      4.0  Санкт-Петербург           31532.0
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 2489                6916.0                  0     498.713409
# 20215               4624.0                  1    2218.000000
#
#        ponds_around_3000  ponds_nearest  days_exposition
# 2489                   3          198.0            102.0
# ...

# %%
data = data.query('kitchen_area < 100')

# %% [markdown]
# Теперь приступим к изменению типа значений в тех столбцах, которые будут необходимы.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22998 non-null  int64
#  1   last_price            22998 non-null  float64
#  2   total_area            22998 non-null  float64
#  3   first_day_exposition  22998 non-null  datetime64[ns]
#  4   rooms                 22998 non-null  int64
#  5   ceiling_height        22998 non-null  float64
#  6   floors_total          22998 non-null  float64
#  7   living_area           22998 non-null  float64
#  8   floor                 22998 non-null  int64
#  9   is_apartment          22998 non-null  bool
#  10  is_studio             22998 non-null  bool
#  11  is_open_plan          22998 non-null  bool
#  12  kitchen_area          22998 non-null  float64
#  13  balcony               22998 non-null  float64
# ...

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %%
data['floors_total'] = data['floors_total'].astype('int') #переведем в целое число

# %%
data['balcony'] = data['balcony'].notnull().astype('int') #переведем в целое число

# %%
data.info() #проверим еще раз
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22998 non-null  int64
#  1   last_price            22998 non-null  float64
#  2   total_area            22998 non-null  float64
#  3   first_day_exposition  22998 non-null  datetime64[ns]
#  4   rooms                 22998 non-null  int64
#  5   ceiling_height        22998 non-null  float64
#  6   floors_total          22998 non-null  int64
#  7   living_area           22998 non-null  float64
#  8   floor                 22998 non-null  int64
#  9   is_apartment          22998 non-null  bool
#  10  is_studio             22998 non-null  bool
#  11  is_open_plan          22998 non-null  bool
#  12  kitchen_area          22998 non-null  float64
#  13  balcony               22998 non-null  int64
#  14  locality_name         22998 non-null  object
# ...

# %% [markdown]
# **Комментарий студента

# %%
data.duplicated().sum() #проверим датафрейм на явные дубликаты
# Out:
# 0

# %% [markdown]
# Проверка показала, что явных дубликатов в датафрейме нет.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая работа. В целом подраздел выполнен качественно.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению забыли посмотреть явные дубликаты, а это основа предобработка данных :( Добавишь проверку?
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# -цена одного квадратного метра;
# -день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# -месяц публикации объявления;
# -год публикации объявления;
# -тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# -расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).

# %%
data['price_to_meter'] = data['last_price'] / data['total_area'] #добавляем в датафрейм новый столбец "цена одного квадратного метра"

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday # день недели
data['month_exposition'] = data['first_day_exposition'].dt.month    # месяц
data['year_exposition'] = data['first_day_exposition'].dt.year    # год

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Совет на будущие работы: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %%
data.head(20) #проверим
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %%
data['floor_number'] = ['другой']*len(data) #для не первого и последнего этажа
data.loc[data['floor'] == 1, 'floor_number'] = 'первый' #первый этаж 
data.loc[data['floor'] == data['floors_total'], 'floor_number'] = 'последний' #последний этаж

# %%
data.head(20) #проверим
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %%
data['to_center_km'] = round(data['city_centers_nearest'] / 1000,0) #делим метры на 1000 и получаем км, округляем до ближайшего целого числа

# %%
data.head(20) #проверим
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 3              0  64900000.0      159.00           2015-07-24      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# ...

# %%
data.info() #проверим
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22998 non-null  int64
#  1   last_price            22998 non-null  float64
#  2   total_area            22998 non-null  float64
#  3   first_day_exposition  22998 non-null  datetime64[ns]
#  4   rooms                 22998 non-null  int64
#  5   ceiling_height        22998 non-null  float64
#  6   floors_total          22998 non-null  int64
#  7   living_area           22998 non-null  float64
#  8   floor                 22998 non-null  int64
#  9   is_apartment          22998 non-null  bool
#  10  is_studio             22998 non-null  bool
#  11  is_open_plan          22998 non-null  bool
#  12  kitchen_area          22998 non-null  float64
#  13  balcony               22998 non-null  int64
#  14  locality_name         22998 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Приступим к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# В этой части построим гистограммы по показателям таблицы и изучим их.

# %% [markdown]
# Построим график разброса для **total_area**. Распределение вне основной части равномерное. Вывод - очевидных выбросов нет.

# %%
data.boxplot(column='total_area')
plt.show()

# %% [markdown]
# Построим гистограмы по столбцам с площадью.

# %% [markdown]
# Total_area. Cудя по гистограмме данных,большая часть объявлений - квартиры с общей площадью 40-50.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, с большей площадью меньше предложений. Объекты выше 90-100 кв. м - это более дорогой сегмент.
# </div>

# %%
data['total_area'].hist(bins = 30, range = (0,300))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Living_AREA** Судя по гистограмме данных,большая часть объявлений - квартиры с жилой площадью 12-15.

# %%
data['living_area'].hist(bins = 30, range = (0,200))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Kitchen_AREA** Судя по гистограмме данных,большая часть объявлений - квартиры с площадью кухни 8-10.

# %%
data['kitchen_area'].hist(bins = 30, range = (0,60))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Посмотрим на взаимосвязь жилой площади к общей площади.

# %%
print(data['total_area'].corr(data['living_area'])) #найдем корреляцию Пирсона по каждому параметру
data['total_area'].corr(data['kitchen_area'])
# Out:
# 0.9156652684832994
# 0.5858654419719758

# %% [markdown]
# Очевидная положительная корреляция общей площади и жилой площади. Чем больше общая площадь, тем больше жилая.
# Корреялция между общей площадью и площадью кухни не столь очевидна, но также положительна. Что в целом соотвествует логике, т.к. планировки кухонь могут быть разными.

# %% [markdown]
# **Last_price**

# %%
data.boxplot(column='last_price')
plt.show()

# %% [markdown]
# Есть отдельные выбросы по квартирам дороже 15 млн рублей.

# %%
data.plot(kind='hist',
y='last_price',
histtype='step', 
range=(0,30000000),
bins=30,
grid=True,
legend=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большая часть объявлений в диапазоне 4-4,5 млн. рублей.

# %% [markdown]
# **Rooms**

# %%
data.boxplot(column='rooms')
plt.show()

# %% [markdown]
# Есть выбросы жилья с количеством комнат больше 6.

# %%
data['rooms'].hist() #строим гистограмму для этого стобца
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть объявлений квартиры с двумя комнатами.

# %% [markdown]
# **Ceiling_height**

# %%
data.boxplot(column='ceiling_height')
plt.show()

# %% [markdown]
# Есть выбросы по высоте потолков ниже 2 метров. Остальное распределение равномерное.

# %%
data['ceiling_height'].hist() #построим гистограмму по этому стобцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть объявлений это жилье с высотой потолков от 2,5 до 3 метров.

# %% [markdown]
# **Floor**

# %%
data['floor'].hist() #строим гистограмму по этому столбцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть объявлений - квартиры с 1 по 5 этаж.

# %% [markdown]
# **Floor_number**

# %%
data['floor_number'].hist() #строим гистограмму по этому столбцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Делаем вывод, что наименее популярны первый и последний этажи.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Да, чаще всего продают не последний и не первый этажи - такие этажи могут быть проблемными (заглядывают прохожие, холодно, жарко, протекает крыша и т.д.)
#
# Также это связано с этажностью строительства. Первый и последний этажи - это лишь по одному этажу, а группа "другой" включает в себя все этажи, кроме первого и последнего. Для 3-этажных домов мы бы увидели равномерное распределение, но строительство заметно выше, чем 3 этажа.
# </div>

# %% [markdown]
# **Floors_total**

# %%
data['floors_total'].hist()
#строим гистограмму по этому столбцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Самое большое кол-во объявлений - квартиры на 5ом этаже.

# %% [markdown]
# **city_centers_nearest**

# %%
data['city_centers_nearest'].hist() #строим гистограмму по этому столбцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть находится в 10 000 метров от центра города.

# %% [markdown]
# **airports_nearest**

# %%
data['city_centers_nearest'].hist(bins = 30) #строим гистограмму по этому столбцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть находится в 18-20 км от аэропорта. Есть всплеск 50-52 км от аэропорта. Можно объяснить наличием населнного пункта на таком удалении с большим кол-вом продаж квартир или ЖК, в котором продаются квартиры.

# %% [markdown]
# **parks_nearest**

# %%
data['parks_nearest'].hist(bins = 30) #строим гистограмму по этому столбцу
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть объявлений в радиусе 500 метров от парков. Можно сделать вывод, что в регионе очень много парков:)

# %% [markdown]
# **weekday_exposition, month_exposition, year_exposition**

# %%
data['weekday_exposition'].hist(bins = 30) #гистограмма по дню недели
# Out:
# <AxesSubplot:>

# %% [markdown]
# Очевидно, что большая часть объявлений публикуется в будние дни. Лидерами являются вторник и четверг.

# %%
data['month_exposition'].hist(bins = 40) #гистгграмма по месяцу публикации
# Out:
# <AxesSubplot:>

# %% [markdown]
# Весна и осень самые популярные времена года для публикаций. Рост начиная с февраля и заканчивая апрелем, и с сентября по ноябрь. Жаркие месяцы (май-август) и новогодние и посленовогодние (декабрь, январь) непопулярны. Предположу, что это связано с большим количеством отпусков.

# %%
data['year_exposition'].hist(bins = 40) #гистгграмма по году публикации
# Out:
# <AxesSubplot:>

# %% [markdown]
# Самые большое кол-во публикаций в 2017-18 годах. С 2014-16 годы положительная динамика публикаций (запуск сервиса и его раскрутка). В 2019 году падение кол-ва публикаций (неполный год).

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍  В целом, праздничные месяцы отличаются меньшим предложением. Это нормально.
# </div>

# %% [markdown]
# **days_exposition**

# %%
data['days_exposition'].hist() #гистограмма по длительности продажи
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))    
data.days_exposition.hist(bins=300)
plt.xlabel('Количество дней')
plt.title('Детальное распределение количества дней')
plt.xlim(0,150)
plt.show() #построим более детальную гистограмму распределения дней

# %% [markdown]
# Видим 2 вслеска на 40-45 день и на 60-65 день. Возможно это связано с повторной публикацией (продлением объявлений), как особенность сервиса Яндекс.Недвижимость

# %%
print(data['days_exposition'].median())
data['days_exposition'].mean() #посмотрим медианное и среднее значения
# Out:
# 97.0
# 182.41339573268922

# %% [markdown]
# Среднее время продажи - полгода. Но вот медианное значение, близкое к реальному показателю 97 дней.

# %%
data['days_exposition'].hist(bins=100, figsize=(10,5)) #посмотрим динамику в гистограмме
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большинство квартир продается в первые 50-80 дней публикации.

# %%
data.boxplot(column='days_exposition') #посмотрим на распределение
# Out:
# <AxesSubplot:>

# %% [markdown]
# Самые быстрые продажи - до 5 дней, после 220 дней - долгие продажи.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# До 1.5 месяцев можно считать быстрой продажей
# </div>

# %%
def correlation_last_price(data, row):
    data = data.pivot_table(
    index=row, 
    values='last_price', 
    aggfunc='mean'
    ).fillna(0)
    display(data)
    ax = data.plot(xticks=data.index)
    ylab = ax.set_ylabel('last_price')

# %%
correlation_last_price(data, 'year_exposition')
plt.title('Зависимость цены от года')
# Out:
#                    last_price
# year_exposition
# 2014             1.223643e+07
# 2015             8.476948e+06
# 2016             6.834559e+06
# 2017             6.404885e+06
# 2018             5.981145e+06
# 2019             6.728126e+06
# Text(0.5, 1.0, 'Зависимость цены от года')

# %% [markdown]
# Стоимость продаж падала до 2018 года, затем начала расти.

# %%
correlation_last_price(data, 'month_exposition')
plt.title('Зависимость цены от месяца')
# Out:
#                     last_price
# month_exposition
# 1                 6.624751e+06
# 2                 6.470852e+06
# 3                 6.361341e+06
# 4                 6.743140e+06
# 5                 6.517471e+06
# 6                 6.303195e+06
# 7                 6.601379e+06
# 8                 6.422694e+06
# 9                 6.531762e+06
# 10                6.137861e+06
# 11                6.514032e+06
# 12                6.600043e+06
# Text(0.5, 1.0, 'Зависимость цены от месяца')

# %% [markdown]
# Рост стоимости жилья в апреле, июле и декабре. Сильное падение стоимости продаж в октябре.

# %%
correlation_last_price(data, 'weekday_exposition')
plt.title('Зависимость цены от месяца')
# Out:
#                       last_price
# weekday_exposition
# 0                   6.452968e+06
# 1                   6.437580e+06
# 2                   6.439725e+06
# 3                   6.696700e+06
# 4                   6.393307e+06
# 5                   6.543157e+06
# 6                   6.319937e+06
# Text(0.5, 1.0, 'Зависимость цены от месяца')

# %% [markdown]
# Рост стоимости продаж в четверг и в субботу. Падение в пятницу и в воскресенье.

# %%
plt.figure(figsize=(12,12))
upp_mat = np.triu(data.corr())
sns.heatmap(data.corr()[['last_price']], vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')
plt.show() #построим тепловую карту, чтобы увидеть корреляцию всех параметров на стоимость квартир

# %% [markdown]
# Логично, что больше всего влияния на стоимость квартир оказывают показатели площади жилья. Также важны высота потолка и количество комнат. Маловажны - этажность дома, наличие парков рядом, аэропортов и наличие балконов.

# %%
sns.relplot(x='total_area', y='last_price',data=data)
plt.title('Зависимость стоимости жилья от общей площади')
plt.show() #посмотрим на зависимость стоимости от общей площади квартиры

# %%
sns.relplot(x='rooms', y='last_price',data=data)
plt.title('Зависимость стоимости жилья от количества комнат')
plt.show() #посмотрим на зависимость стоимости от количества комнат

# %% [markdown]
# Рассмотрев подробнее, видим положительную корреляюцию между стоимостью жилья и количеством комнат и общей площадью жилья.

# %% [markdown]
# Рассмотрим зависимость между стоимостью жилья и расположением жилья на этажах.

# %%
data.pivot_table(index='floor_number',values='last_price', aggfunc='median').reset_index() 
#посмотрим на медианные значения по типу этажа
# Out:
#   floor_number  last_price
# 0       другой   4900000.0
# 1       первый   3950000.0
# 2    последний   4350000.0

# %%
sns.relplot(x='last_price', y='floor_number',data=data)
plt.title('Зависимость стоимости жилья от количества комнат')
plt.show() #посмотрим на зависимость стоимости от типа этажа

# %% [markdown]
# Стоимость квартир на не последнем и первом этаже выше.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верная интерпретация полученных данных.
# </div>

# %% [markdown]
# **Посмотрим на объявления в разрезе места нахождения**

# %%
top_10= data[data.locality_name.isin(data.locality_name.value_counts().index[:10])] 
# топ-10 населенных пунктов по к-ву объявлений

# %%
fig, ax = plt.subplots(figsize=(12, 12)) 

for locality in top_10.locality_name.unique():
    sns.kdeplot(top_10[top_10.locality_name == locality].price_to_meter, label = locality)

plt.legend(bbox_to_anchor = (1,1))
plt.title('Распределение за квадратный метр по населенным пунктам')
plt.xlabel('Цена за квадратный метр')
plt.xlim((0,250000))
plt.show() #посомтрим на цену за кв по разным регионам

# %%
display(top_10.pivot_table(index='locality_name', values='price_to_meter',  aggfunc='mean')
        .sort_values(by='price_to_meter')
        .round(2)) #построим таблицу-список населенных пунктов со средней ценой за метр
# Out:
#                    price_to_meter
# locality_name
# Выборг                   58064.11
# Гатчина                  68699.55
# Всеволожск               68751.74
# Колпино                  75430.27
# поселок Шушары           78157.61
# поселок Мурино           84513.28
# поселок Парголово        90262.96
# деревня Кудрово          91894.17
# Пушкин                  103109.96
# Санкт-Петербург         114339.55

# %% [markdown]
# Самые низкие цены за квадратный метр в Выборге и Гатчине, самые высокие в Пушкине и в Санкт-Петербурге.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам.
#
#
#
# </div>

# %% [markdown]
# **Теперь посмотрим отдельно в Санкт-Петербурге**

# %%
data['city_centers_nearest_in_km'] = data['city_centers_nearest'].div(1000).fillna(0).apply(np.ceil)
spb = data[data['locality_name'] == 'Санкт-Петербург']
spb.sample(3) #создаем 2 столбца
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 6271             13   4890000.0        44.5           2019-02-25      2
# 11057            10   2700000.0        35.0           2017-10-13      1
# 17047            13   8500000.0        78.2           2018-01-19      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 6271             2.50             5         30.5      2         False  ...
# 11057            2.76            15         19.0     13         False  ...
# 17047            3.30             6         49.0      4         False  ...
#
#        ponds_around_3000  ponds_nearest  days_exposition  price_to_meter  \
# 6271                   0            NaN             14.0   109887.640449
# 11057                  1           48.0             11.0    77142.857143
# 17047                  0            NaN             98.0   108695.652174
#
#       weekday_exposition  month_exposition  year_exposition  floor_number  \
# ...

# %%
spb_pivot= spb.pivot_table(index = 'city_centers_nearest_in_km', values= 'price_to_meter', aggfunc='mean')
display(spb_pivot.head(10))
spb_pivot.plot(figsize=(12,10))
plt.show() #создаем сводную таблицу с двумя столбцами: расстояние до центра в км и цена за квадратный метр
# Out:
#                             price_to_meter
# city_centers_nearest_in_km
# 1.0                          184165.181041
# 2.0                          166526.459848
# 3.0                          147115.663351
# 4.0                          125872.725000
# 5.0                          136533.611368
# 6.0                          144892.857701
# 7.0                          151536.482927
# 8.0                          140986.726687
# 9.0                          119725.970288
# 10.0                         109904.411793

# %% [markdown]
# Видим очевидную корреляцию. Чем ближе к центру, тем выше стоимость квартир.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍  Верно, дальше от центра - дешевле квартиры.
# </div>

# %%
plt.figure(figsize=(12,12)) 
upp_mat = np.triu(spb.corr())
sns.heatmap(spb.corr()[['last_price']], vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')
plt.show() #построим тепловую карту коррелияции, чтобы посмотреть влияние остальных параметров

# %% [markdown]
# Корреляция такая же, как и в целом по всем регионам: площадь, количество комнат, высоат потолков.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# **Описание проекта
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
# Ваша задача — выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
# О каждой квартире в базе содержится два типа данных: добавленные пользователем и картографические. Например, к первому типу относятся площадь квартиры, её этаж и количество балконов, ко второму — расстояния до центра города, аэропорта и ближайшего парка.
#
# На этапе предобработки:
# 1. Работа с пропусками (удалены, заменены)
# 2. Работа с дубликатами (исправлены, удалены)
# 3. Изменены типы данных, там где необходимо.
# 4. Найдены и устранены выбивающиеся данные.
#
#
# **Выводы исследования.
#
# Основные показатели, которые влияют на стоимость жилья это:
# общая площадь;
# соотношение площади кухни и жилой площади к общей;
# количество комнат;
# высота потолка;
# этаж (последний, другой);
#
# При изучении объявлений в Санкт-Птербурга выявлено, что факторы примерно такие же:
#
# общая площадь;
# жилая площадь и площадь кухни;
# количество комнат;
# наличию парка рядом.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:https://habr.com/ru/company/otus/blog/540526/, https://pythonru.com/biblioteki/seaborn-plot
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Этибар, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Твою работу очень интересно читать и проверять.  Я оставил одну обязательную поправку для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Этибар, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 😊👍
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [х]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [х]  определены пропущенные значения
# - [х]  заполнены пропущенные значения там, где это возможно
# - [х]  есть пояснение, какие пропущенные значения обнаружены
# - [х]  изменены типы данных
# - [х]  есть пояснение, в каких столбцах изменены типы и почему
# - [х]  устранены неявные дубликаты в названиях населённых пунктов
# - [х]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [х]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [х]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [х]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [х]  посчитано и добавлено в таблицу: год публикации объявления
# - [х]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [х]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [х]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [х]  построены гистограммы для каждого параметра
# - [х]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [х]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [х]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [х]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [х]  в каждом этапе есть промежуточные выводы
# - [х]  есть общий вывод
