# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <b>Привет, Этибар!👋
#
# Меня зовут Эльвира, я буду ревьюером твоего проекта. Предлагаю общаться на «ты», но если это не удобно - дай мне знать, и мы перейдем на «вы».
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Такими комментариями я буду помечать отлично проделаную работу😉
# </div>
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# В таких комментариях я постараюсь подсказать тебе более элегантное или легкое решение, некоторые хитрости и фишки. Части проекта, помеченные такими комментариями, можно не исправлять, но рекомендую обратить на них внимание.</div>
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера ⛔️<a class="tocSkip"></h2>
#
# В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Если ты видишь такой комментарий, значит здесть есть недочет, который следует исправить.
# </div>
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница🙃
#
# `<div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>`
#
# Чтобы сделать подобный блок, кликни здесь дважды и скопируй всю предыдущую строку ;)
#
# Пожалуйста, не удаляй и не перемещай мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.</div></b>

# %% [markdown]
# **Цель проекта - посмотреть на гипотезы, приоритезировать их. Имея на руках данные А/В теста, поможем определить, что деать дальше с тестом: остановить или продолжить**

# %% [markdown]
# <span style="color:blue">**Часть 1. Гипотезы**</span>

# %% [markdown]
# `<div class="alert alert-info"> <b>В этой части, посмотрим какие гипотезы были выдвинуты и как можем их приоритезировать.
# Важно учесть полезность гипотез, охваты, значимость и влияние.</b> </div>`

# %% [markdown]
# Файл /datasets/hypothesis.csv.
#
# Hypothesis — краткое описание гипотезы;
#
# Reach — охват пользователей по 10-балльной шкале;
#
# Impact — влияние на пользователей по 10-балльной шкале;
#
# Confidence — уверенность в гипотезе по 10-балльной шкале;
#
# Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.

# %% [markdown]
# <span style="color:blue">**Часть 2. Тест**</span>

# %% [markdown]
# <div class="alert alert-info">
# В этой части рассчитаем кумулятивные значения, посмотреть на результаты двух групп, сравнить их между собой и рекомендовать, что делать дальше с тестом. <a class="tocSkip">

# %% [markdown]
# Файл /datasets/orders.csv.
#
# transactionId — идентификатор заказа;
#
# visitorId — идентификатор пользователя, совершившего заказ;
#
# date — дата, когда был совершён заказ;
#
# revenue — выручка заказа;
#
# group — группа A/B-теста, в которую попал заказ.
#
# Файл /datasets/visitors.csv.
#
# date — дата;
#
# group — группа A/B-теста;
#
# visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Введение можно улучшить, если в описании проекта мы выделим основные задачи и опишем их своими словами, особенно с позиции бизнес задачи, которая решается. Удалим инструкцию к проекту, поскольку она предназначена для студентов и не несет никакой информации для заказчиков. Так же можно добавить краткий план работы, основные этапы, которые мы должны выполнить и оставить описание данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# <span style="color:blue">**Часть 1. Гипотезы**</span>

# %% [markdown]
# Для начала импортируем библиотеку и прочитаем датасет.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime as dt
import scipy.stats as stats
import warnings

from scipy import stats as st
#импортируем библиотеку

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Молодец, что загружаешь все библиотеки в начале проекта. Так сложней случайно удалить ячейку с загрузкой нужной библиотеки и сделать код не работающим. А получатель отчета сразу поймет, какие библиотеки ты используешь и какие ему нужно установить для запуска проекта.
#
# Все ли библиотеки используются? Лучше оставить только используемые в данном проекте)
# </div>

# %%
# снимаем ограничение на количество столбцов
pd.set_option('display.max_columns', None)

# снимаем ограничение на ширину столбцов
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv('/datasets/hypothesis.csv')
display(data)
#прочитали файл и посмотрим на таблицу
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %%
data.info()
#данные о таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %%
data.columns = data.columns.str.lower()
data
#приведем названия столбцов к нижнему регистру
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# В таблице 9 гипотез и оценки по 10-бальной шкале по 4 параметрам. Цель - приоритезировать гипотезы, используя 2 метода ICE и RICE.

# %% [markdown]
# **ICE**

# %%
data['ICE'] = round((data['impact'] * data['confidence'] / data['efforts']),2)
display(data[['hypothesis', 'ICE']].sort_values(by = 'ICE', ascending = False))
#сделаем приоритезацию в фреймворке ICE по убывающей значимости
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
#  Для отображения таблиц лучше использовать display(), вместо print().

# %% [markdown]
# В этом фреймворке Топ значимых гипотез - Запустить акцию, Добавить 2 новых канала траффика, Добавить форму подписки на все основные страницы.

# %% [markdown]
# **Посмотрим под другим соусом - RICE.**

# %%
data['RICE'] = round((data['reach'] * data['impact'] * data['confidence'] / data['efforts']),2)
display(data[['hypothesis', 'RICE']].sort_values(by = 'RICE', ascending = False))
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# В фреймворке RICE топ продуктивных гипотез: Добавить форму подписки на все основные страницы, Добавить блоки рекомендаций товаров на сайт, Добавить 2 новых каналапривлечения траффика.

# %%
data[['hypothesis', 'ICE', 'RICE']].sort_values(by = 'RICE', ascending = False).head(5)
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
#
#      ICE   RICE
# 7  11.20  112.0
# 2   7.00   56.0
# 0  13.33   40.0
# 6   8.00   40.0
# 8  16.20   16.2

# %% [markdown]
# Видим, что в фреймворке RICE, значимость гипотез изменилась, т.к. добавился параметр Reach, который оценивает скольких пользователей коснется изменение.
# Исходя из этого, значимость некоторых гипотез выросла.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Приоритизация гипотез проведена успешно! Молодец, что выводишь таблицу дважды, каждый раз с сортировкой по одному из фреймоврков, так различия в их работе будут максимально наглядными. Согласна с твоими выводами по поводу их различия.

# %% [markdown]
# <span style="color:blue">**Часть 2. Анализ A/B-теста**</span>

# %%
orders = pd.read_csv('/datasets/orders.csv')

visitors = pd.read_csv('/datasets/visitors.csv')

#прочитаем файлы

# %%
display(orders.head())
visitors.head()
#взглянем на таблицы
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %%
print(orders.info())
visitors.info()
#посмотрим детальнее
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
orders.rename(columns = {'transactionId':'transaction_id', 'visitorId':'visitor_id'}, inplace = True)
orders.head()
#нижний регистр двух столбцов
# Out:
#    transaction_id  visitor_id        date  revenue group
# 0      3667963787  3312258926  2019-08-15     1650     B
# 1      2804400009  3642806036  2019-08-15      730     B
# 2      2961555356  4069496402  2019-08-15      400     A
# 3      3797467345  1196621759  2019-08-15     9759     B
# 4      2282983706  2322279887  2019-08-15     2308     B

# %%
orders['date'] = pd.to_datetime(orders['date'])
visitors['date'] = pd.to_datetime(visitors['date'])
#приведем к формату даты

# %%
display(orders.duplicated().sum())
visitors.duplicated().sum()
#проверим на дубликаты
# Out:
# 0
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Можно провести дополнительные исследования, например:
#
# * Посмотреть сколько у нас групп в АВ-тесте;
# * Изучить временной интервал, узнав даты начала и окончания теста;
# * Рассмотреть количество пользователей в каждой группе - по таблице с заказами;
# * Посмотреть не попадают ли какие-то пользователи в обе группы - по таблице с заказами.
# * Посмотреть динамику посетителей по дням по группам (visitos).
# </div>

# %% [markdown]
# **2.1 Куммулятивная выручка по группам**

# %% [markdown]
# Необходимо создать единую таблицу, содержащую данные о датах, группах и кумулятивных значениях.

# %%
grouped_1 = orders[['date', 'group']].drop_duplicates()

grouped_1 = grouped_1.apply(
    lambda x: orders[
        np.logical_and(
            orders['date'] <= x['date'], orders['group'] == x['group']
        )
    ].agg(
        {
            'date': 'max',
            'group': 'max',
            'transaction_id': 'nunique',
            'visitor_id': 'nunique',
            'revenue': 'sum',
        }
    ),
    axis=1,
).sort_values(by=['date', 'group'])

grouped_1.head(10)
# Out:
#           date group  transaction_id  visitor_id  revenue
# 55  2019-08-01     A              24          20   148579
# 66  2019-08-01     B              21          20   101217
# 175 2019-08-02     A              44          38   242401
# 173 2019-08-02     B              45          43   266748
# 291 2019-08-03     A              68          62   354874
# 310 2019-08-03     B              61          59   380996
# 499 2019-08-04     A              84          77   425699
# 498 2019-08-04     B              78          75   489567
# 698 2019-08-05     A             109         100   549917
# 699 2019-08-05     B             101          98   581995

# %% [markdown]
# Теперь получим агрегированные значения с куммулятивами с таблице с посетителями.

# %%
grouped_2 = grouped_1.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], visitors['group'] == x['group']
        )
    ].agg(
        {
            'date': 'max', 
            'group': 'max', 
            'visitors': 'sum'
        }
    ),
    axis=1,
).sort_values(by=['date', 'group'])

grouped_2.head(10)
# Out:
#           date group  visitors
# 55  2019-08-01     A       719
# 66  2019-08-01     B       713
# 175 2019-08-02     A      1338
# 173 2019-08-02     B      1294
# 291 2019-08-03     A      1845
# 310 2019-08-03     B      1803
# 499 2019-08-04     A      2562
# 498 2019-08-04     B      2573
# 698 2019-08-05     A      3318
# 699 2019-08-05     B      3280

# %%
cummulative_table = grouped_1.merge(grouped_2, 
                                    left_on = ['date', 'group'], 
                                    right_on = ['date', 'group'])
cummulative_table.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']
#объединим все в одну таблицу

# %%
cummulative_table['conversion'] = cummulative_table['orders'] / cummulative_table['visitors']
#посчитаем коверсию
cummulative_table['av_check'] = round(cummulative_table['revenue'] / cummulative_table['orders'],0)
# и средний чек
cummulative_table.head()
# Out:
#         date group  orders  buyers  revenue  visitors  conversion  av_check
# 0 2019-08-01     A      24      20   148579       719    0.033380    6191.0
# 1 2019-08-01     B      21      20   101217       713    0.029453    4820.0
# 2 2019-08-02     A      44      38   242401      1338    0.032885    5509.0
# 3 2019-08-02     B      45      43   266748      1294    0.034776    5928.0
# 4 2019-08-03     A      68      62   354874      1845    0.036856    5219.0

# %% [markdown]
# Теперь построим график куммулятивной выручки по группам.

# %%
cum_rev_a = cummulative_table[cummulative_table['group'] == 'A'][['date', 'revenue', 'orders']]
cum_rev_b = cummulative_table[cummulative_table['group'] == 'B'][['date', 'revenue', 'orders']]

plt.plot(cum_rev_a['date'], cum_rev_a['revenue'], label = 'A')
plt.plot(cum_rev_b['date'], cum_rev_b['revenue'], label = 'B')
plt.ylabel('Выручка, млн.рублей')
plt.title('Динамика куммулятивной выручки по группам', color = 'Blue')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Можно убрать технические строчки перед графиком, добавив `plt.show()` или `;`. </div>

# %% [markdown]
# Куммулятивная выручка группы В больше куммулятивной выручки группы А. При этом 18 августа произошел скачок выручки в группе В.

# %% [markdown]
# Явная причина такого большого скачка в выручке - это выбросы. Какой-то посетитель сделал покупку значительно больше среднего чека, что привело к резкому росту кумулятивной выручки группы В.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера ⛔️<a class="tocSkip"></h2>
# <s>
# Необходимо указать возможные причины такого резкого скачка)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓 v_2 <a class="tocSkip"> </h2>
#
# Сейчас при анализе графика мы не учитываем, что на графике виден рост выручки. Если упростить, то выручка = конверсия * средний чек. Если выручка выросла, то мог увеличится средний чек, а могло увеличится количество заказов (т.е. конверсия).
#
# Здесь нужно дать полное описание возможных причин такого поведения графика. Если мы предлагаем только одну причину скачка, можно предположить, что мы не вполне понимаем всю картину.

# %% [markdown]
# **2.2 Куммулятивный средний чек по группам.**

# %%
cum_check_a = cummulative_table[cummulative_table['group'] == 'A'][['date', 'av_check', 'orders']]
cum_check_b = cummulative_table[cummulative_table['group'] == 'B'][['date', 'av_check', 'orders']]

plt.plot(cum_check_a['date'], cum_check_a['av_check'], label = 'A')
plt.plot(cum_check_b['date'], cum_check_b['av_check'], label = 'B')
plt.ylabel('Выручка, млн.рублей')
plt.title('Динамика среднего чека по группам', color = 'Blue')
plt.xticks(rotation=90)
plt.legend();

# %% [markdown]
# Исключая 1,2,13,14 августа, средний чек группы В выше среднего чека группы А. В среднем чеке тоже видим всплеск в группе В 18 августа. Предположу, что в этот день была/и совершены дорогие покупки, повлиявшие и на средний чек, и на выручку.

# %% [markdown]
# **2.3 График относительного изменения кумулятивного среднего чека группы B к группе A**

# %%
cum_rev_ab = cum_rev_a.merge(
    cum_rev_b, 
    left_on='date', 
    right_on='date', 
    how='left', 
    suffixes=['_a', '_b']
)


# cтроим отношение средних чеков
plt.plot(cum_rev_ab['date'], 
         (
             cum_rev_ab['revenue_b']/cum_rev_ab['orders_b']
         )/
         (
             cum_rev_ab['revenue_a']/cum_rev_ab['orders_a']
         )-1
        )
# добавляем ось X
plt.axhline(y=0, color='red', linestyle='--')
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A', color = 'Blue')
plt.ylabel('Пункт изменения')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# График неровный, со скачками. Необходимо посомтреть не имеют ли место выбросы.

# %% [markdown]
# **2.4 Кумулятивное среднее количество заказов на посетителя по группам**

# %%
cummulative_table_a = cummulative_table[cummulative_table['group']=='A']
cummulative_table_b = cummulative_table[cummulative_table['group']=='B']
#распределим разные группы

plt.plot(cummulative_table_a['date'], cummulative_table_a['conversion'], label='A')
plt.plot(cummulative_table_b['date'], cummulative_table_b['conversion'], label='B')
plt.legend()
plt.title('Кумулятивная конверсия по группам', color = 'Blue')
plt.ylabel('Конверсия')
plt.xticks(rotation=90)
plt.show()
#построим график куммулятивной конверсии

# %% [markdown]
# Конверсия группы В выглядит лучше конверсии группы А. Но динамика графика группа А положительная, а группы В - отрицательная.

# %% [markdown]
# **2.5 График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A**

# %%
сummulative_сonversion_ab = cummulative_table_a[['date','conversion']].merge(cummulative_table_b[['date','conversion']], 
                                                                   left_on='date', 
                                                                   right_on='date', 
                                                                   how='left', 
                                                                   suffixes=['_a', '_b'])
plt.plot(сummulative_сonversion_ab['date'], сummulative_сonversion_ab['conversion_b']/сummulative_сonversion_ab['conversion_a']-1)
plt.title('Относительное изменение кумулятивной конверсии группы В к группе А', color = 'Blue')
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.1, color='grey', linestyle='--')
plt.xticks(rotation=90)
plt.show()
#строим график

# %% [markdown]
# Группа В резко выросла в конверсии относительно группы А. Важно помнить, что в данных могут быть выбросы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Графики построены и интерпретированы верно, молодец)
# </div>

# %% [markdown]
# **2.6 Точечный график количества заказов по пользователям.**

# %%
orders_by_users = (
    orders.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)
orders_by_users.columns =  ['visitor_id', 'orders']

plt.hist(orders_by_users['orders']) 
plt.title('Количество заказов по пользователям', color = 'Blue')
plt.xlabel('Заказы')
plt.ylabel('Пользователи')
plt.show()
#строим график

# %% [markdown]
# Большинство пользователей оформляют не больше 1 заказа, но есть и те, кто оформлял больше 2.

# %%
x_values = pd.Series(range(0, len(orders_by_users)))
plt.scatter(x_values, orders_by_users['orders'])
plt.title('Точечный график количества заказов на покупателя', color = 'Blue')
plt.ylabel('Кол-во заказов')
plt.xlabel('Кол-во пользователей')
plt.show()
#строим точечный график

# %% [markdown]
# Точечный график показывает, что есть покупатели, которые заказывают даже больше 10.

# %% [markdown]
# **2.7 Узнаем 95-й и 99-й перцентили количества заказов на пользователя и выберем границу для определения аномальных пользователей.**

# %%
np.percentile(orders_by_users['orders'], [95, 99])
#узнаем 95 и 99 перцентиль
# Out:
# array([2., 4.])

# %% [markdown]
# 5% пользователей делали покупки более 2ух и только 1% - более 4ех. Возьмем за верхнюю границу **4 заказа.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Верно)

# %% [markdown]
# **2.8 Точечный график стоимостей заказов**

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))
plt.scatter(x_values, orders['revenue'])
plt.title('Точечный график стоимости заказов на пользователя', color = 'Blue')
plt.ylabel('Кол-во пользователей')
plt.xlabel('Стоимость заказа')
plt.show()

# %% [markdown]
# Есть заказы 100 и 200 тысяч. Точно выбросы.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
# Можно добавить еще один график, ограничив значения по оси Y. Чтобы двух явных выбросов не было видно, а мы могли рассмотреть основную часть заказов.

# %% [markdown]
# **2.9 Посчитать 95-й и 99-й перцентили стоимости заказов и выбрать границу для определения аномальных заказов.**

# %%
np.percentile(orders['revenue'], [95, 99])
#узнаем 95 и 99 перцентиль
# Out:
# array([28000. , 58233.2])

# %% [markdown]
# Определим за верхнюю границу 58 233.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Хорошая работа по определению границ аномальных значений)

# %% [markdown]
# **2.10 Статистическая значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным**

# %% [markdown]
# Посчитаем статистическую значимость различий в конверсии между группами по «сырым» данным — без удаления аномальных пользователей.
#
# Для этого введем 2 гипотезы:
#
# Основная гипотеза (Н0) - различий в конверсии между группами нет.
#
# Альтернативная гипотеза (Н1) - различие в конверсии между группами есть.

# %%
visitors_a_daily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitors_a_daily.columns = ['date', 'visitors_per_date_a']

visitors_a_cummulative = visitors_a_daily.apply(
    lambda x: visitors_a_daily[visitors_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_a': 'sum'}
    ),
    axis=1,
)
visitors_a_cummulative.columns = ['date', 'visitors_a_cummulative']

visitors_b_daily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitors_b_daily.columns = ['date', 'visitors_per_date_b']

visitors_b_cummulative = visitors_b_daily.apply(
    lambda x: visitors_b_daily[visitors_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_b': 'sum'}
    ),
    axis=1,
)
visitors_b_cummulative.columns = ['date', 'visitors_b_cummulative']

orders_a_daily = (
    orders[orders['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
orders_a_daily.columns = ['date', 'orders_per_date_a', 'revenue_per_date_a']

orders_a_cummulative = orders_a_daily.apply(
    lambda x: orders_a_daily[orders_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_a': 'sum', 'revenue_per_date_a': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_a_cummulative.columns = [
    'date',
    'orders_cummulative_a',
    'revenue_cummulative_a',
]

orders_b_daily = (
    orders[orders['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
orders_b_daily.columns = ['date', 'orders_per_date_b', 'revenue_per_date_b']

orders_b_cummulative = orders_b_daily.apply(
    lambda x: orders_b_daily[orders_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_b': 'sum', 'revenue_per_date_b': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_b_cummulative.columns = [
    'date',
    'orders_cummulative_b',
    'revenue_cummulative_b',
]

data = (
    orders_a_daily.merge(
        orders_b_daily, left_on='date', right_on='date', how='left'
    )
    .merge(orders_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(orders_b_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_a_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_b_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_b_cummulative, left_on='date', right_on='date', how='left')
)
data.head(10)
#создадим датасет рассчетам на пользователя по группам
# Out:
#         date  orders_per_date_a  revenue_per_date_a  orders_per_date_b  \
# 0 2019-08-01                 24              148579                 21
# 1 2019-08-02                 20               93822                 24
# 2 2019-08-03                 24              112473                 16
# 3 2019-08-04                 16               70825                 17
# 4 2019-08-05                 25              124218                 23
# 5 2019-08-06                 18               48484                 28
# 6 2019-08-07                 18              142417                 24
# 7 2019-08-08                 16               96279                 27
# 8 2019-08-09                 16              188506                 25
# 9 2019-08-10                 16              210495                 23
#
#    revenue_per_date_b  orders_cummulative_a  revenue_cummulative_a  \
# 0              101217                    24                 148579
# ...

# %% [markdown]
# Таблица со столбцами:
#
# date — дата;
#
# orders_daily_a — количество заказов в выбранную дату в группе A;
#
# revenue_per_date_a — суммарная выручка в выбранную дату в группе A;
#
# orders_daily_a — количество заказов в выбранную дату в группе B;
#
# revenue_per_date_a — суммарная выручка в выбранную дату в группе B;
#
# orders_cummulative_a — суммарное число заказов до выбранной даты включительно в группе A;
#
# revenue_cummulative_a — суммарная выручка до выбранной даты включительно в группе A;
#
# orders_cummulative_b — суммарное количество заказов до выбранной даты включительно в группе B;
#
# revenue_cummulative_b — суммарная выручка до выбранной даты включительно в группе B;
#
# visitors_per_date_a — количество пользователей в выбранную дату в группе A;
#
# visitors_per_date_b — количество пользователей в выбранную дату в группе B;
#
# visitors_cummulative_a — количество пользователей до выбранной даты включительно в группе A;
#
# visitors_cummulative_b — количество пользователей до выбранной даты включительно в группе B.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Нужно ли нам собирать всю таблицу, если мы используем не все показатели в расчетах?)

# %%
orders_by_users_a = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_a.columns = ['visitor_id', 'orders']

orders_by_users_b = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_b.columns = ['visitor_id', 'orders']
#создаем 2 переменные

# %%
example_a = pd.concat([orders_by_users_a['orders'],
                      pd.Series(
                          0, 
                          index=np.arange(data['visitors_per_date_a'].sum() - 
                                          len(orders_by_users_a['orders'])), 
                          name='orders')],axis=0
                    )

example_b = pd.concat([orders_by_users_b['orders'],
                      pd.Series(
                          0, 
                          index=np.arange(data['visitors_per_date_b'].sum() - 
                                          len(orders_by_users_b['orders'])), 
                          name='orders')],axis=0
                    )
#объявили 2 переменные для дальнейших тестов

# %%
def diff_function(data_a, data_b):
    alpha = 0.05
    p_value = stats.mannwhitneyu(data_a, data_b)[1]
    print("P-value: {0:.3f}".format(p_value))

    if (p_value < alpha):
        print("Отвергаем нулевую гипотезу")
    else:
        print("Не получилось отвергнуть нулевую гипотезу")
    
    print("Относительный прирост В к А: {0:.3%}".format(data_b.mean() / data_a.mean()-1))
#создадим функцию, которая будет проверять гипотезы

# %% [markdown]
# Зададим уровень значимости alpha = 0.05.
# Выведем различие между группами В и А.

# %%
diff_function(example_a, example_b)
#передадим функции переменные
# Out:
# P-value: 0.017
# Отвергаем нулевую гипотезу
# Относительный прирост В к А: 13.808%

# %% [markdown]
# По сырым данным различие между группами есть (p-value < alpha). Отвергаем нулевую гипотезу, относительный выигрыш группы В = 13,8%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
# Гипотезы сформулированы верно и значение p-value интерпретировано правильно. Хорошая работа.
# </div>

# %% [markdown]
# **2.11 Статистическая значимость различий в среднем чеке на посетителя между группами по «сырым» данным**

# %% [markdown]
# Посчитаем статистическую значимость различий в среднем чеке между группами по «сырым» данным — без удаления аномальных пользователей.
#
# Для этого введем 2 гипотезы:
#
# Основная гипотеза (Н0) - различий в среднем чеке между группами нет.
#
# Альтернативная гипотеза (Н1) - различие в среднем чеке между группами есть.

# %%
diff_function(orders[orders['group'] == 'A']['revenue'], orders[orders['group'] == 'B']['revenue'])
# Out:
# P-value: 0.729
# Не получилось отвергнуть нулевую гипотезу
# Относительный прирост В к А: 25.871%

# %% [markdown]
# P-value больше, чем alpha. Нулевую гипотезу не отвергаем. Относительный прирост В к А - 25,8%

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Стоит дополнить, что поскольку относительное различие среднего чека между сегментами составляет ~26%, наблюдаемые различия не являются значимыми при таком уровне значимости, а следовательно были получены случайно. </div>

# %% [markdown]
# **2.12 Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.**

# %%
users_with_many_orders = pd.concat(
    [
        orders_by_users_a[orders_by_users_a['orders'] > 4]['visitor_id'],
        orders_by_users_b[orders_by_users_b['orders'] > 4]['visitor_id'],
    ],
    axis=0,
)
users_with_expensive_orders = orders[orders['revenue'] > 58233]['visitor_id']
abnormal_users = (
    pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values()
)
sample_a_filtered = pd.concat(
    [
        orders_by_users_a[
            np.logical_not(orders_by_users_a['visitor_id'].isin(abnormal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_a'].sum() - len(orders_by_users_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sample_b_filtered = pd.concat(
    [
        orders_by_users_b[
            np.logical_not(orders_by_users_b['visitor_id'].isin(abnormal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_b'].sum() - len(orders_by_users_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)
#очистим данные, исходя из тех пределов, которые выбрали ранее

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Чтобы в дальнейшем мы могли использовать анализ повторно, будет лучше отказаться от  ручного ввода обозначаемых границ, и заменить на соответствующие коду обозначения (перцентили))
#
# </div>

# %%
diff_function(sample_a_filtered, sample_b_filtered)
# Out:
# P-value: 0.014
# Отвергаем нулевую гипотезу
# Относительный прирост В к А: 15.331%

# %% [markdown]
# На очищенных данных разница между группами есть (p-value < alpha). Нулевую гипотезу отвергаем. Относительная разница между группами 15,3%.

# %% [markdown]
# **2.13 Статистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным.**

# %%
diff_function(
    orders[(orders['group']=='A') & np.logical_not(orders['visitor_id'].isin(abnormal_users))]['revenue'], 
    orders[(orders['group']=='B') & np.logical_not(orders['visitor_id'].isin(abnormal_users))]['revenue'])
#посчитаем с помощью функции по очищенным данным
# Out:
# P-value: 0.851
# Не получилось отвергнуть нулевую гипотезу
# Относительный прирост В к А: -0.575%

# %% [markdown]
# По очищенным данным разницы между группами в среднем чеке нет (p-value > alpha). Относительная разница между группой В к А -0,6% (разницы практически нет).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Статистический анализ проведен верно)

# %% [markdown]
# <span style="color:blue">**Выводы**</span>

# %% [markdown]
# На основании данных предыдущих исследований и данных от отдела маркетинга, была проведена аналитическая работа.
#
# 1. С применением разных фреймворков были приоритезированы гипотезы.
#
# 2. На основании данных о заказах и визитах двух групп, проанализированы гипотезы.
#
# 3. Ниже рекомендации на основании аналитики.

# %% [markdown]
# **Часть 1. Приоритезация гипотез.**

# %% [markdown]
# В части приоритезации гипотез рекомендую обратить внимание на:
#
# 1. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
#
# 2. Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
#
# Эти 2 гипотезы входят в топ-3 в обоих фреймворках проверки. Следственно, имеют большую ценность.

# %% [markdown]
# **Часть 2. Анализ А/В теста**

# %% [markdown]
# 1. Как по "сырым", так и по очищенным данным среднее кол-во заказов группы В больше группы А.
#
# 2. Данные кумулятивной конверсии группы группы В выше конверсии группы А.
#
# 3. Как по "сырым", так и по очищенным данным различий в среднем чеке между группами нет.

# %% [markdown]
# <span style="color:orange">**Рекомендация - остановаить А/В тест, т.к. результаты группы В в конверсии значительно лучше группы А.**</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Верно)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊 v_2<a class="tocSkip"> </h2>
#     <br/>
# Этибар, спасибо за проект! Успехов в дальнейшем обучении!)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊<a class="tocSkip"> </h2>
#     <br/>
# Этибар, замечательная работа по проекту, отлично справился с расчетами и графиками)
#
# Необходимо доработать:
#
# * Добавить комментарий к графику
# * Остальные комментарии ты найдешь в работе
#
#
# **Желаю удачи и жду твой проект на повторное ревью! Если вдруг у тебя возникнут вопросы, то я с радостью отвечу на них.    😊**
#
# <br>
#
# **Дополнительные материалы:**
#
# [Вебинары под эгидой Практикума](https://vk.com/yandex.praktikum?w=wall-176471180_2144),
#
# [Лекции Анатолия Карпова 1](https://www.youtube.com/watch?v=jnFVmtaeSA0&list=WL&index=19&t=2s) [2](https://www.youtube.com/watch?v=gljfGAkgX_o&list=WL&index=4)
#
# Материалы [gopractice](https://gopractice.ru/summary/)
#
# Лекцию Карта статистических методов [Смотреть видео](https://www.youtube.com/watch?v=-zps6hm0nX8&t=1269s)
#
# </div>
